# %%
from utils.processbronz import *

# %%
volume = "/Volumes/workspace/myschema/source_data"
file_name = "customer_data.csv"
table_name = file_name.split("_")[0]
path = f"{volume}/{file_name}"

# %%
def processBronz():
    df = getData(path, True)
    clean_df = clean_column(df)
    writeBronz(clean_df, table_name)

# %%
def main():
    processBronz()

# %%
main()
